# %% [markdown]
# Step-1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path = "C:\\Users\\Kishan D K\\OneDrive\\Documents\\Data_science\\Data_files\\visadataset.csv"

# %%
file_path
# Out:
# 'C:\\Users\\Kishan D K\\OneDrive\\Documents\\Data_science\\Data_files\\visadataset.csv'

# %%
visa_df = pd.read_csv(file_path)

# %%
visa_df
# Out:
#        case_id continent education_of_employee has_job_experience  \
# 0    EZYV00001    Europe           High School                  N
# 1    EZYV00002  North Am            Bachelor's                  N
# 2    EZYV00003      Asia           High School                  Y
# 3    EZYV00004  North Am            Bachelor's                  N
# 4    EZYV00005    Africa             Doctorate                  N
# ..         ...       ...                   ...                ...
# 195  EZYV00196    Africa            Bachelor's                  Y
# 196  EZYV00197    Europe              Master's                  Y
# 197  EZYV00198    Africa           High School                  Y
# 198  EZYV00199  North Am              Master's                  N
# 199  EZYV00200    Africa            Bachelor's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                       Y            12815         1986                South
# ...

# %%
visa_df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visa_df.continent
# Out:
# 0        Europe
# 1      North Am
# 2          Asia
# 3      North Am
# 4        Africa
#          ...
# 195      Africa
# 196      Europe
# 197      Africa
# 198    North Am
# 199      Africa
# Name: continent, Length: 200, dtype: object

# %%
len(visa_df)
# Out:
# 200

# %%
visa_df.head
# Out:
# <bound method NDFrame.head of        case_id continent education_of_employee has_job_experience  \
# 0    EZYV00001    Europe           High School                  N
# 1    EZYV00002  North Am            Bachelor's                  N
# 2    EZYV00003      Asia           High School                  Y
# 3    EZYV00004  North Am            Bachelor's                  N
# 4    EZYV00005    Africa             Doctorate                  N
# ..         ...       ...                   ...                ...
# 195  EZYV00196    Africa            Bachelor's                  Y
# 196  EZYV00197    Europe              Master's                  Y
# 197  EZYV00198    Africa           High School                  Y
# 198  EZYV00199  North Am              Master's                  N
# 199  EZYV00200    Africa            Bachelor's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# ...

# %%
visa_df.head()
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 0  EZYV00001    Europe           High School                  N
# 1  EZYV00002  North Am            Bachelor's                  N
# 2  EZYV00003      Asia           High School                  Y
# 3  EZYV00004  North Am            Bachelor's                  N
# 4  EZYV00005    Africa             Doctorate                  N
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     Y            12815         1986                South
# 1                     Y            58485         1955            Northeast
# 2                     Y            31262         1904              Midwest
# 3                     Y            42617         1993              Midwest
# 4                     Y            69628         1909            Northeast
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0        100248.93         Year                  N   Certified
# ...

# %%
visa_df['continent']
# Out:
# 0        Europe
# 1      North Am
# 2          Asia
# 3      North Am
# 4        Africa
#          ...
# 195      Africa
# 196      Europe
# 197      Africa
# 198    North Am
# 199      Africa
# Name: continent, Length: 200, dtype: object

# %%
visa_df[['continent']]     # it comes as a title [continent]
cols = ['continent']
visa_df[cols]
# Out:
#     continent
# 0      Europe
# 1    North Am
# 2        Asia
# 3    North Am
# 4      Africa
# ..        ...
# 195    Africa
# 196    Europe
# 197    Africa
# 198  North Am
# 199    Africa
#
# [200 rows x 1 columns]

# %%
cols = ['continent','case_status']
visa_df[cols]
# Out:
#     continent case_status
# 0      Europe   Certified
# 1    North Am   Certified
# 2        Asia   Certified
# 3    North Am   Certified
# 4      Africa      Denied
# ..        ...         ...
# 195    Africa      Denied
# 196    Europe      Denied
# 197    Africa   Certified
# 198  North Am      Denied
# 199    Africa      Denied
#
# [200 rows x 2 columns]

# %% [markdown]
# **********Uniqe**********

# %%
print(visa_df['continent'].unique()) # it will print
len(visa_df['continent'].unique())    # it will count
# Out:
# ['Europe' 'North Am' 'Asia' 'Africa']
# 4

# %%
# insead of len(..........) use [nunique]
visa_df['continent'].nunique()
# Out:
# 4

# %%
visa_df['continent']=='Africa'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 195     True
# 196    False
# 197     True
# 198    False
# 199     True
# Name: continent, Length: 200, dtype: bool

# %%
visa_df[visa_df['continent']=='Asia']
# Out:
#        case_id continent education_of_employee has_job_experience  \
# 2    EZYV00003      Asia           High School                  Y
# 7    EZYV00008      Asia           High School                  N
# 8    EZYV00009      Asia              Master's                  Y
# 13   EZYV00014      Asia           High School                  Y
# 18   EZYV00019      Asia           High School                  N
# 21   EZYV00022      Asia             Doctorate                  Y
# 22   EZYV00023      Asia             Doctorate                  Y
# 30   EZYV00031      Asia             Doctorate                  Y
# 33   EZYV00034      Asia             Doctorate                  N
# 37   EZYV00038      Asia              Master's                  Y
# 45   EZYV00046      Asia            Bachelor's                  N
# 46   EZYV00047      Asia             Doctorate                  N
# 55   EZYV00056      Asia              Master's                  Y
# ...

# %%
length = visa_df[visa_df['continent']=='Asia']
len(length)
# Out:
# 49

# %%
length = visa_df[visa_df['continent']=='Africa']
len(length)
# Out:
# 48

# %%
length = visa_df[visa_df['continent']=='Austrilia']
len(length)
# Out:
# 0

# %%
length = visa_df[visa_df['continent']=='North Am']
len(length)
# Out:
# 50

# %%
continent = visa_df['continent'].unique()
for i in continent:
    count = len(visa_df[visa_df['continent']==i])
    print(i,':',count)
# Out:
# Europe : 53
# North Am : 50
# Asia : 49
# Africa : 48

# %%
count = []
continent = visa_df['continent'].unique()
for i in continent:
    c = len(visa_df[visa_df['continent']==i])
    count.append(c)
    #print(i,':',count)
count
# Out:
# [53, 50, 49, 48]

# %%
continent = visa_df['continent'].unique()
count = [len(visa_df[visa_df['continent']==i]) for i in continent]
count,continent
# Out:
# ([53, 50, 49, 48],
#  array(['Europe', 'North Am', 'Asia', 'Africa'], dtype=object))

# %%
list_1 = ['continent','South America','Asia']
list_2 = ['count','50', '49', '48']
pd.DataFrame(zip(list_1,list_2))
# Out:
#                0      1
# 0      continent  count
# 1  South America     50
# 2           Asia     49

# %%
file_path = "C:\\Users\\Kishan D K\\OneDrive\\Documents\\Data_science\\Data_files\\visadataset.csv"

# %%
file_path
# Out:
# 'C:\\Users\\Kishan D K\\OneDrive\\Documents\\Data_science\\Data_files\\visadataset.csv'

# %%
visa_df = pd.read_csv(file_path)

# %%
visa_df
# Out:
#        case_id continent education_of_employee has_job_experience  \
# 0    EZYV00001    Europe           High School                  N
# 1    EZYV00002  North Am            Bachelor's                  N
# 2    EZYV00003      Asia           High School                  Y
# 3    EZYV00004  North Am            Bachelor's                  N
# 4    EZYV00005    Africa             Doctorate                  N
# ..         ...       ...                   ...                ...
# 195  EZYV00196    Africa            Bachelor's                  Y
# 196  EZYV00197    Europe              Master's                  Y
# 197  EZYV00198    Africa           High School                  Y
# 198  EZYV00199  North Am              Master's                  N
# 199  EZYV00200    Africa            Bachelor's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                       Y            12815         1986                South
# ...

# %%
continents = visa_df['continent'].unique()
count = [len(visa_df[visa_df['continent']==i])for i in continents]
pd.DataFrame(zip(continent,count),columns = ['continents','count'])
continents_df.to_csv('continents_info.csv', index=False)

# %%
# Get unique continents
continents = visa_df['continent'].unique()

# Count rows for each continent
count = [len(visa_df[visa_df['continent'] == i]) for i in continents]

# Create a DataFrame
continents_df = pd.DataFrame(zip(continents, count), columns=['continents', 'count'])

# Save to CSV
continents_df.to_csv('continents_info.csv', index=False)

# %%
visa_df['continent'].value_counts()
# Out:
# continent
# Europe      53
# North Am    50
# Asia        49
# Africa      48
# Name: count, dtype: int64

# %%
pd.Series(count,index=continents)
# Out:
# Europe      53
# North Am    50
# Asia        49
# Africa      48
# dtype: int64

# %%
# How to create a DataFrame using value_count and Series
visa_df['continent'].value_counts()


# In order to create a dataframe
# We need two lists
# Or one dictionary

# From value counts create two lists
# index
# keys
# Out:
# continent
# Europe      53
# North Am    50
# Asia        49
# Africa      48
# Name: count, dtype: int64

# %%
visa_df['continent'].value_counts().keys()
# Out:
# Index(['Europe', 'North Am', 'Asia', 'Africa'], dtype='object', name='continent')

# %%
# From value counts create two lists
# index
# keys

visa_df['continent'].value_counts().keys()
visa_df['continent'].value_counts().values
# Out:
# array([53, 50, 49, 48], dtype=int64)

# %%
# Method 1
continents = visa_df['continent'].value_counts().keys()
count = visa_df['continent'].value_counts().values
pd.DataFrame(zip(continents,count),columns = ['continent','count'])
# Out:
#   continent  count
# 0    Europe     53
# 1  North Am     50
# 2      Asia     49
# 3    Africa     48

# %%
#Convert into dictionary
# Method 2
dict1=dict(visa_df['continent'].value_counts())
print(dict1)
pd.DataFrame(dict1,index = ['count'])
# Out:
# {'Europe': 53, 'North Am': 50, 'Asia': 49, 'Africa': 48}
#        Europe  North Am  Asia  Africa
# count      53        50    49      48

# %%
dict1=dict(visa_df['continent'].value_counts())
print(dict1)
pd.DataFrame(dict1,index = ['count'])
# Out:
# {'Europe': 53, 'North Am': 50, 'Asia': 49, 'Africa': 48}
#        Europe  North Am  Asia  Africa
# count      53        50    49      48

# %%
# Method 3
dict1=dict(visa_df['continent'].value_counts())
dict1.keys()
dict1.values()
pd.DataFrame(zip(dict1.keys(),dict1.values()))
# Out:
#           0   1
# 0    Europe  53
# 1  North Am  50
# 2      Asia  49
# 3    Africa  48

# %%
continents_df
# Out:
#   continents  count
# 0     Europe     53
# 1   North Am     50
# 2       Asia     49
# 3     Africa     48

# %%
# continents = categorical
# count = numerical
# we can plot Bar plot and Pi chart using this

# %% [markdown]
# $Bar-plot$

# %% [markdown]
# - x-axis = categorical data
#
# - y-axis = numerical data
#
# - Where you are taking the data : continents_df

# %%
plt.bar('continents','count',data = continents_df)
# Out:
# <BarContainer object of 4 artists>

# %%
# Method 1
visa_df['continent'].value_counts()
continents = visa_df['continent'].value_counts().keys()
count = visa_df['continent'].value_counts().values
pd.DataFrame(zip(continents,count),columns = ['continent','count'])

plt.bar('continent','count',data = continents_df)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.figure(figsize=(8,5))
# 8 is horizontal scale x
# 5 is verticle scale y
plt.bar('continents','count',data = continents_df)
plt.title('Bar--chart')
plt.savefig('continents_bar.jpg')
plt.xlabel('continent')
plt.ylabel('count')
plt.show()
