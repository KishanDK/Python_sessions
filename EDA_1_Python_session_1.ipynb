# %% [markdown]
# #########################Packages#################
# *************************EDA**********************
# 1) Pandas - Dataframe analysis
# 2) numpy  - numerical python/ number python
# 3) Mathplotlib - plot
# 4) seaborn - plot
# 5) plotly - plot
# 6) bokhe - plot
# ************************ML************************
# 7) scikit-learn - sklearn
# ************************DL************************
# 8) tensorflow
# 9) keras
# 10) pytorch
# 11) open cv (CV) : Computer Vision
# ************************NLP************************
# 12)NLTK
# 13)Scipy
# **********************GenerativeAI*****************
# 14) Chatgpt : openAI
# 15) Makersuit : google generative ai
# 16) Amazon Q
# ***************************Hugging face transformation(BERT)*******************************
# 17)Transformers
# ***************************Others*********************************************
# random
# math
# os
# sys
# time

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path = "C:\\Users\\Kishan D K\\OneDrive\\Documents\\Data_science\\Data_files\\visadataset.csv"
pd.read_csv(file_path)
# Out:
#        case_id continent education_of_employee has_job_experience  \
# 0    EZYV00001    Europe           High School                  N
# 1    EZYV00002  North Am            Bachelor's                  N
# 2    EZYV00003      Asia           High School                  Y
# 3    EZYV00004  North Am            Bachelor's                  N
# 4    EZYV00005    Africa             Doctorate                  N
# ..         ...       ...                   ...                ...
# 195  EZYV00196    Africa            Bachelor's                  Y
# 196  EZYV00197    Europe              Master's                  Y
# 197  EZYV00198    Africa           High School                  Y
# 198  EZYV00199  North Am              Master's                  N
# 199  EZYV00200    Africa            Bachelor's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                       Y            12815         1986                South
# ...

# %%
list1 = ['Ram','Raheem','Robert']
list2 = [30,31,32]
pd.DataFrame(zip(list1,list2))
# Out:
#         0   1
# 0     Ram  30
# 1  Raheem  31
# 2  Robert  32

# %%
# To give column name
list1 = ['Ram','Raheem','Robert']
list2 = [30,31,32]
names = pd.DataFrame(zip(list1,list2),columns = ['Name','Age'])
names
# Out:
#      Name  Age
# 0     Ram   30
# 1  Raheem   31
# 2  Robert   32

# %%
# What is your dataframe name : names
# Where you want to save : C:\Users\Kishan D K\OneDrive\Documents\Data_science\Data_files
# What name you want to provide : NAMES_data
names.to_csv("C:\\Users\\Kishan D K\\OneDrive\\Documents\\Data_science\\Data_files\\NAMES_data.csv")

# %%
# if we dont provide the location, then it will save in the location where your python file located
names.to_csv("NAMES_data.csv")

# %%
# it will not create extra column as index
# By giving index = False [it will remove the first empty column]
names.to_csv("NAMES_1_data.csv",index = False)

# %% [markdown]
# $task1$

# %% [markdown]
# # Read the NAMES_data and NAMES_1_data

# %%
#By analysing the difference btw NAMES_data and NAMES_1_data , you will know whats the use of [index = False]

# %%
file_path = "Names_data.csv"
pd.read_csv(file_path)
# Out:
#    Unnamed: 0    Name  Age
# 0           0     Ram   30
# 1           1  Raheem   31
# 2           2  Robert   32

# %%
# to avoid the Unnamed:0
file_path = "Names_1_data.csv"
pd.read_csv(file_path)
# Out:
#      Name  Age
# 0     Ram   30
# 1  Raheem   31
# 2  Robert   32

# %% [markdown]
# $Step - 5$

# %% [markdown]
# #########ADD a new column to existing dataframe#############

# %%
# What is your dataframe name : names
# What is the name of the new column : City
# How many rows we have in Original column : 3
# What is your new data : ['Hydrabad','Chennai','Bangalore']

names['city'] = ['Hydrabad','Chennai','Bangalore']
names
# Out:
#      Name  Age       city
# 0     Ram   30   Hydrabad
# 1  Raheem   31    Chennai
# 2  Robert   32  Bangalore

# %% [markdown]
# $Step - 6$
# # How to drop the column #

# %%
# what is your data frame name : name
******************************************
# I want to drop column
# axis=1 =========== columns
# axis=0 =========== rows
******************************************
# what is the name of the column: city
******************************************
# inplace
# when you are drop the column means
#     you are modifying the table
#     the dataframe overwrite or
#     you want to create a dataframe

# inplace=True : data will be overwrite

# %%
names
# Out:
#      Name  Age
# 0     Ram   30
# 1  Raheem   31
# 2  Robert   32

# %%
names['city'] = ['Hydrabad','Bangalore','Chennai',]
names
# Out:
#      Name  Age       city
# 0     Ram   30   Hydrabad
# 1  Raheem   31  Bangalore
# 2  Robert   32    Chennai

# %%
names.drop('city',axis=1, inplace = True)    # here inplace is to overwrite this in a same location(names) olny
names
# Out:
#      Name  Age
# 0     Ram   30
# 1  Raheem   31
# 2  Robert   32

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ********Creating DataFrame using Dictionary********

# %%
dict1 = {'Names' : ['Ram','Raheem','Robert'],
        'Age' : [30,31,32]}
dict1
# Out:
# {'Names': ['Ram', 'Raheem', 'Robert'], 'Age': [30, 31, 32]}

# %%
pd.DataFrame(dict1)
# Out:
#     Names  Age
# 0     Ram   30
# 1  Raheem   31
# 2  Robert   32

# %%
pd.DataFrame(dict1,index=['a','b','c'])
# Out:
#     Names  Age
# a     Ram   30
# b  Raheem   31
# c  Robert   32

# %%
pd.DataFrame(dict1,columns=['String','int'])
# Out:
# Empty DataFrame
# Columns: [String, int]
# Index: []
