# %% [markdown]
# $Step-1$

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path = "C:\\Users\\Kishan D K\\OneDrive\\Documents\\Data_science\\Data_files\\visadataset.csv"

# %%
file_path
# Out:
# 'C:\\Users\\Kishan D K\\OneDrive\\Documents\\Data_science\\Data_files\\visadataset.csv'

# %%
visa_df = pd.read_csv(file_path)
visa_df
# Out:
#        case_id continent education_of_employee has_job_experience  \
# 0    EZYV00001    Europe           High School                  N
# 1    EZYV00002  North Am            Bachelor's                  N
# 2    EZYV00003      Asia           High School                  Y
# 3    EZYV00004  North Am            Bachelor's                  N
# 4    EZYV00005    Africa             Doctorate                  N
# ..         ...       ...                   ...                ...
# 195  EZYV00196    Africa            Bachelor's                  Y
# 196  EZYV00197    Europe              Master's                  Y
# 197  EZYV00198    Africa           High School                  Y
# 198  EZYV00199  North Am              Master's                  N
# 199  EZYV00200    Africa            Bachelor's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                       Y            12815         1986                South
# ...

# %% [markdown]
# **************Shape - It will give you the number of frows and columns***************

# %%
visa_df.shape
# Out:
# (200, 12)

# %%
type(visa_df)
# Out:
# pandas.core.frame.DataFrame

# %%
print("The number of Rows are",visa_df.shape[0])
print("The number of Columns are",visa_df.shape[1])
# Out:
# The number of Rows are 200
# The number of Columns are 12

# %%
visa_df.size
# Out:
# 2400

# %%
visa_df.shape[0]*visa_df.shape[1]
# Out:
# 2400

# %%
visa_df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
type(visa_df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
visa_df.columns.to_list
# Out:
# <bound method IndexOpsMixin.tolist of Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')>

# %%
# Bound methods means use the brackets
# Not callable means remove the brackets

# %%
visa_df.columns.to_list()
# Out:
# ['case_id',
#  'continent',
#  'education_of_employee',
#  'has_job_experience',
#  'requires_job_training',
#  'no_of_employees',
#  'yr_of_estab',
#  'region_of_employment',
#  'prevailing_wage',
#  'unit_of_wage',
#  'full_time_position',
#  'case_status']

# %%
type(visa_df.columns)
# Out:
# pandas.core.indexes.base.Index

# %% [markdown]
# $dtypes$

# %%
visa_df.dtypes
# object means categorical columns
# int64 and float64
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object

# %%
# it is series type
type(visa_df.dtypes)
# Out:
# pandas.core.series.Series

# %%
visa_df.dtypes.keys()
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visa_df.dtypes.index
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visa_df.dtypes.values
# Out:
# array([dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'),
#        dtype('int64'), dtype('int64'), dtype('O'), dtype('float64'),
#        dtype('O'), dtype('O'), dtype('O')], dtype=object)

# %%
type(visa_df.dtypes.values)
# Out:
# numpy.ndarray

# %% [markdown]
# $Head$

# %%
visa_df.head()    #it willgive you the top 5 rows in a dataframe from the index starting from 0
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 0  EZYV00001    Europe           High School                  N
# 1  EZYV00002  North Am            Bachelor's                  N
# 2  EZYV00003      Asia           High School                  Y
# 3  EZYV00004  North Am            Bachelor's                  N
# 4  EZYV00005    Africa             Doctorate                  N
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     Y            12815         1986                South
# 1                     Y            58485         1955            Northeast
# 2                     Y            31262         1904              Midwest
# 3                     Y            42617         1993              Midwest
# 4                     Y            69628         1909            Northeast
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0        100248.93         Year                  N   Certified
# ...

# %%
visa_df.head(2)
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 0  EZYV00001    Europe           High School                  N
# 1  EZYV00002  North Am            Bachelor's                  N
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     Y            12815         1986                South
# 1                     Y            58485         1955            Northeast
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0        100248.93         Year                  N   Certified
# 1         36080.79         Year                  Y   Certified

# %%
visa_df.tail()   # it will give last 5 rows
# Out:
#        case_id continent education_of_employee has_job_experience  \
# 195  EZYV00196    Africa            Bachelor's                  Y
# 196  EZYV00197    Europe              Master's                  Y
# 197  EZYV00198    Africa           High School                  Y
# 198  EZYV00199  North Am              Master's                  N
# 199  EZYV00200    Africa            Bachelor's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 195                     N            14629         2004                 West
# 196                     Y             7504         2012                 West
# 197                     Y            43149         1900                South
# 198                     Y           111098         1888                South
# 199                     N           140121         1981              Midwest
#
#      prevailing_wage unit_of_wage full_time_position case_status
# ...

# %%
# if i want specific row
# use take()
list1 = ['80','90','100']
visa_df.take(list1)
# Out:
#        case_id continent education_of_employee has_job_experience  \
# 80   EZYV00081    Europe           High School                  N
# 90   EZYV00091      Asia           High School                  Y
# 100  EZYV00101  North Am            Bachelor's                  N
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 80                      N            25484         1937                South
# 90                      N            55575         1986            Northeast
# 100                     N            62319         1941            Northeast
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 80         142096.36         Hour                  Y   Certified
# 90          56242.66         Year                  N   Certified
# 100         82819.99         Year                  N   Certified

# %%
visa_df.take(['80','90','100'], axis = 0)  # axis 0 will give the rows which is specified by the take()
# Out:
#        case_id continent education_of_employee has_job_experience  \
# 80   EZYV00081    Europe           High School                  N
# 90   EZYV00091      Asia           High School                  Y
# 100  EZYV00101  North Am            Bachelor's                  N
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 80                      N            25484         1937                South
# 90                      N            55575         1986            Northeast
# 100                     N            62319         1941            Northeast
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 80         142096.36         Hour                  Y   Certified
# 90          56242.66         Year                  N   Certified
# 100         82819.99         Year                  N   Certified

# %% [markdown]
# ****Task** -
# ********I want 80,90,100 rows from 6,9,10 columns**********

# %%
visa_df.take(['6','9','10'], axis = 1).take(['80','90','100']) # axis 1 will give the columns which is specified by the take()
# Out:
#      yr_of_estab unit_of_wage full_time_position
# 80          1937         Hour                  Y
# 90          1986         Year                  N
# 100         1941         Year                  N

# %% [markdown]
# $Iloc----- and ------Loc$

# %%
visa_df.iloc(<rows>,<columns>)

# %%
visa_df.iloc[100:150]  # it will give only rows from 100 to 150
# Out:
#        case_id continent education_of_employee has_job_experience  \
# 100  EZYV00101  North Am            Bachelor's                  N
# 101  EZYV00102      Asia            Bachelor's                  Y
# 102  EZYV00103    Europe             Doctorate                  Y
# 103  EZYV00104    Europe            Bachelor's                  Y
# 104  EZYV00105  North Am            Bachelor's                  N
# 105  EZYV00106    Africa           High School                  N
# 106  EZYV00107    Africa             Doctorate                  N
# 107  EZYV00108    Europe           High School                  N
# 108  EZYV00109    Europe              Master's                  Y
# 109  EZYV00110  North Am           High School                  N
# 110  EZYV00111    Europe             Doctorate                  Y
# 111  EZYV00112    Europe            Bachelor's                  N
# 112  EZYV00113    Europe            Bachelor's                  Y
# ...

# %%
visa_df.iloc[100:150,2:4]    # it will give both rows[100 to 150] and columns[2 to 4]
# Out:
#     education_of_employee has_job_experience
# 100            Bachelor's                  N
# 101            Bachelor's                  Y
# 102             Doctorate                  Y
# 103            Bachelor's                  Y
# 104            Bachelor's                  N
# 105           High School                  N
# 106             Doctorate                  N
# 107           High School                  N
# 108              Master's                  Y
# 109           High School                  N
# 110             Doctorate                  Y
# 111            Bachelor's                  N
# 112            Bachelor's                  Y
# 113             Doctorate                  N
# 114           High School                  N
# 115             Doctorate                  Y
# 116            Bachelor's                  N
# 117              Master's                  N
# 118             Doctorate                  N
# 119           High School                  N
# ...

# %% [markdown]
# ******iloc will take only numbers******

# %%
# to avoid that we use loc
visa_df.loc[[100,120,130],'case_status']    # we can specify the column which we want using the column name
# Out:
# 100    Certified
# 120    Certified
# 130    Certified
# Name: case_status, dtype: object

# %%
rows = [100,150,160]
cols = ['continent', 'case_status']
visa_df.loc[rows,cols]
# Out:
#     continent case_status
# 100  North Am   Certified
# 150    Africa   Certified
# 160      Asia   Certified

# %%
len(visa_df)
# Out:
# 200

# %% [markdown]
# $is-null$

# %%
# any missing values in the data?
# if any, then :True
# if not, then :False
visa_df.isnull()
# Out:
#      case_id  continent  education_of_employee  has_job_experience  \
# 0      False      False                  False               False
# 1      False      False                  False               False
# 2      False      False                  False               False
# 3      False      False                  False               False
# 4      False      False                  False               False
# ..       ...        ...                    ...                 ...
# 195    False      False                  False               False
# 196    False      False                  False               False
# 197    False      False                  False               False
# 198    False      False                  False               False
# 199    False      False                  False               False
#
#      requires_job_training  no_of_employees  yr_of_estab  \
# 0                    False            False        False
# ...
