# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pyplot
import seaborn as sns

# %%
file_path = "C:\\Users\\Kishan D K\\OneDrive\\Documents\\Data_science\\Data_files\\Visa_Data.csv"
file_path
# Out:
# 'C:\\Users\\Kishan D K\\OneDrive\\Documents\\Data_science\\Data_files\\Visa_Data.csv'

# %%
visa_df = pd.read_csv(file_path)
visa_df
# Out:
#           case_id continent education_of_employee has_job_experience  \
# 0      CASE000001      Asia            Bachelor's                  N
# 1      CASE000002      Asia           High School                  Y
# 2      CASE000003    Africa              Master's                  N
# 3      CASE000004      Asia             Doctorate                  N
# 4      CASE000005  North Am              Master's                  N
# ...           ...       ...                   ...                ...
# 25475  CASE025476    Europe           High School                  N
# 25476  CASE025477  North Am              Master's                  Y
# 25477  CASE025478    Europe            Bachelor's                  Y
# 25478  CASE025479      Asia            Bachelor's                  N
# 25479  CASE025480    Europe            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            75525         1955
# ...

# %%
visa_df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visa_df['prevailing_wage']   # Series
# Out:
# 0         43008.072168
# 1         43097.517365
# 2         80843.447168
# 3        102855.597809
# 4         61660.054111
#              ...
# 25475     21913.638366
# 25476     33380.784536
# 25477     74712.757623
# 25478     71138.069839
# 25479    136642.824029
# Name: prevailing_wage, Length: 25480, dtype: float64

# %%
visa_df['prevailing_wage'].values
# Out:
# array([ 43008.07216817,  43097.51736519,  80843.44716782, ...,
#         74712.75762264,  71138.06983949, 136642.82402916])

# %%
visa_df.dtypes
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object

# %% [markdown]
# - count
# - min
# - max
# - mean
# - median

# %%
wage = visa_df['prevailing_wage']
wage.count()
# Out:
# 25480

# %%
wage.min()
# Out:
# 6702.906652372431

# %%
wage.max()
# Out:
# 3238450.898456728

# %%
wage.mean()
# Out:
# 81460.06226580615

# %%
wage.median()
# Out:
# 60936.38470742894

# %%
dict1 = {}                                                    #creating empty dictionary
wage_count = round(visa_df['prevailing_wage'].count(),2)      # Counts how many values are in the column prevailing_wage and rounds it to 2 decimals.
wage_min = round(visa_df['prevailing_wage'].min(),2)          #Finds the minimum wage value and rounds it.
wage_max = round(visa_df['prevailing_wage'].max(),2)
wage_mean = round(visa_df['prevailing_wage'].mean(),2)                                                     #Finds the maximum wage value and rounds it.
wage_median = round(visa_df['prevailing_wage'].median(),2)    #Finds the median (middle) wage value and rounds it.
wage_std = round(visa_df['prevailing_wage'].std(),2)
dict1['count']=wage_count
dict1['min']=wage_min                                         #Stores all the calculated values into the dictionary with proper keys.
dict1['max']=wage_max
dict1['mean']=wage_mean
dict1['median']=wage_median
dict1['std']=wage_std
dict1                                                         #Displays the dictionary with results.
pd.DataFrame(dict1,index=['prevailing_wage'])                 #Converts the dictionary into a DataFrame (table) with one row named "prevailing_wage".
# Out:
#                  count      min        max      mean    median        std
# prevailing_wage  25480  6702.91  3238450.9  81460.06  60936.38  105155.06

# %%
wage_count = round(visa_df['prevailing_wage'].count(),2)      
wage_min = round(visa_df['prevailing_wage'].min(),2)          
wage_max = round(visa_df['prevailing_wage'].max(),2)
wage_mean = round(visa_df['prevailing_wage'].mean(),2)   
wage_median = round(visa_df['prevailing_wage'].median(),2)    
wage_std = round(visa_df['prevailing_wage'].std(),2)

list1 = [wage_count,wage_min,wage_max,wage_mean,wage_median,wage_std]

pd.DataFrame(list1,
             columns = ['prevailing_wage'],
             index = ['count','min','max','mean','median','std'])
# Out:
#         prevailing_wage
# count          25480.00
# min             6702.91
# max          3238450.90
# mean           81460.06
# median         60936.38
# std           105155.06

# %%
#step-1: numerical column list
dtypes=dict(visa_df.dtypes)
num=[i for i in dtypes if dtypes[i]!='O']
print(num)

dict1={}
for i in num:
    count=round(visa_df[i].count(),2)
    MIN=round(visa_df[i].min(),2)
    MAX=round(visa_df[i].max(),2)
    mean=round(visa_df[i].mean(),2)
    median=round(visa_df[i].median(),2)
    std=round(visa_df[i].std(),2)
    list1=[count,MIN,MAX,mean,median,std]
    dict1[i]=list1

df=pd.DataFrame(dict1,
             index=['count','min','max','mean','median','std'])
dict1
# Out:
# ['no_of_employees', 'yr_of_estab', 'prevailing_wage']
# {'no_of_employees': [25480, 11, 99998, 49897.25, 49871.5, 28996.97],
#  'yr_of_estab': [25480, 1900, 2022, 1961.23, 1961.0, 35.5],
#  'prevailing_wage': [25480, 6702.91, 3238450.9, 81460.06, 60936.38, 105155.06]}

# %%
visa_df.describe()
# Out:
#        no_of_employees   yr_of_estab  prevailing_wage
# count     25480.000000  25480.000000     2.548000e+04
# mean      49897.245290   1961.234929     8.146006e+04
# std       28996.966472     35.500881     1.051551e+05
# min          11.000000   1900.000000     6.702907e+03
# 25%       24699.000000   1931.000000     4.318707e+04
# 50%       49871.500000   1961.000000     6.093638e+04
# 75%       75180.000000   1992.000000     8.721287e+04
# max       99998.000000   2022.000000     3.238451e+06

# %%
visa_df['prevailing_wage'].mean()      #reading a specific column and applying methods....like mean, mode, median...etc
# Out:
# 81460.06226580615

# %%
visa_df['prevailing_wage'].median()
# Out:
# 60936.38470742894

# %%
visa_df['prevailing_wage'].mode()
# Out:
# 0        6.702907e+03
# 1        7.679353e+03
# 2        9.199836e+03
# 3        9.513952e+03
# 4        1.004045e+04
#              ...
# 25475    2.027172e+06
# 25476    2.050364e+06
# 25477    2.098850e+06
# 25478    2.206932e+06
# 25479    3.238451e+06
# Name: prevailing_wage, Length: 25480, dtype: float64

# %% [markdown]
# *****percentile and quantile*****

# %% [markdown]
# - percentile range from 1 to 100
# - quantile q1 = 25p, q2 = 50p, q3 = 75p
# - np.percentile(<direct number between 1 to 100>, data)
# - example = np.percentile(75,data)
# - np.quantile(<decimal number>, data)
# - example = np.quantile(0.75,data)

# %%
q1 = round(np.percentile(visa_df['prevailing_wage'],25),2)
q2 = round(np.percentile(visa_df['prevailing_wage'],50),2)
q3 = round(np.percentile(visa_df['prevailing_wage'],75),2)
print(q1,q2,q3)
# Out:
# 43187.07 60936.38 87212.87

# %%
q1 = round(np.quantile(visa_df['prevailing_wage'],0.25),2)
q2 = round(np.quantile(visa_df['prevailing_wage'],0.50),2)
q3 = round(np.quantile(visa_df['prevailing_wage'],0.75),2)
print(q1,q2,q3)
# Out:
# 43187.07 60936.38 87212.87

# %%
dtypes=dict(visa_df.dtypes)
num=[i for i in dtypes if dtypes[i]!='O']
print(num)

dict1={}
for i in num:
    count=round(visa_df[i].count(),2)
    MIN=round(visa_df[i].min(),2)
    MAX=round(visa_df[i].max(),2)
    mean=round(visa_df[i].mean(),2)
    median=round(visa_df[i].median(),2)
    std=round(visa_df[i].std(),2)
    ###########################################################
    q1 = round(np.percentile(visa_df[i],0.25),2)
    q2 = round(np.percentile(visa_df[i],0.50),2)
    q3 = round(np.percentile(visa_df[i],0.75),2)

    
    list1=[count,MIN,MAX,mean,median,std,q1,q2,q3]
    dict1[i]=list1

    df=pd.DataFrame(dict1,
                 index=['count','min','max','mean','median','std','25','50','75'])
dict1
# Out:
# ['no_of_employees', 'yr_of_estab', 'prevailing_wage']
# {'no_of_employees': [25480,
#   11,
#   99998,
#   49897.25,
#   49871.5,
#   28996.97,
#   246.4,
#   457.0,
#   686.28],
#  'yr_of_estab': [25480,
#   1900,
#   2022,
#   1961.23,
#   1961.0,
#   35.5,
#   1900.0,
#   1900.0,
#   1900.0],
#  'prevailing_wage': [25480,
#   6702.91,
#   3238450.9,
#   81460.06,
#   60936.38,
#   105155.06,
#   14943.57,
#   16820.3,
#   17725.63]}

# %% [markdown]
# df

# %%
q1 = round(np.percentile(visa_df['prevailing_wage'],25),2)
q1
# Out:
# 43187.07

# %%
25*156192.00/100
# Out:
# 39048.0

# %% [markdown]
# ******here what is the meaning of that value 64444.57 is ?******
#
# ******25% of data below 64444.57******
#
# ******25% of the observations from the total data have a value below 64444.57******

# %%
visa_df['prevailing_wage'].count()
# Out:
# 25480

# %%
25*25480/100
# Out:
# 6370.0

# %%
len([visa_df['prevailing_wage']<6370.0])
# Out:
# 1

# %% [markdown]
# $Empiricle$-$rule$

# %% [markdown]
# <img src="https://builtin.com/sites/www.builtin.com/files/styles/ckeditor_optimize/public/inline-images/1_empirical-rule.jpg" jsaction="" class="sFlh5c FyHeAf iPVvYb" style="max-width: 810px; height: 152px; margin: 0px; width: 304px;" alt="Empirical Rule (68-95-99.7) Explained | Built In" jsname="kn3ccd">

# %% [markdown]
# **when data shows a normal distribution**
# - u-1*sigma to u+1*sigma : 68%
# - u-2*sigma to u+2*sigma : 95%
# - u-3*sigma to u+3*sigma : 99.7%

# %%
wage_mean,  wage_std
# Out:
# (81460.06, 105155.06)

# %%
# wage_mean = u
# wage_std = sigma

# %%
val_minus_1 = round(wage_mean-1*wage_std,2)
val_plus_1 = round(wage_mean+1*wage_std,2)
val_minus_2 = round(wage_mean-2*wage_std,2)
val_plus_2 = round(wage_mean+2*wage_std,2)
val_minus_3 = round(wage_mean-3*wage_std,2)
val_plus_3 = round(wage_mean+3*wage_std,2)

print(val_minus_1,val_plus_1,val_minus_2,val_plus_2,val_minus_3,val_plus_3)
# Out:
# -23695.0 186615.12 -128850.06 291770.18 -234005.12 396925.24

# %% [markdown]
# - 68 percentage of the observations have values between [58221.85  to  125652.19]
#
# - 95 percentage of the observations have values between [24506.68  to 159367.36]
#
# - 99.7 percentage of the observations have values between [-9208.49 to  193082.53]

# %%
68*25480/100
# Out:
# 17326.4

# %%
con1 = visa_df['prevailing_wage']>val_minus_1
con2 = visa_df['prevailing_wage']<val_plus_1
len(visa_df[con1 & con2])
# Out:
# 24504

# %%
len(visa_df[con1 & con2])/len(visa_df)
# Out:
# 0.9616954474097331

# %% [markdown]
# - 68% should fall between (u - sigma) and (u + sigma) when data is normal. #(according to the above image)
# - But.....
# - the above data ste is not normal, so only 19.5% fall in that range. #(according to my data 19.5%)

# %%
con3 = visa_df['prevailing_wage']>val_minus_2
con4 = visa_df['prevailing_wage']<val_plus_2
len(visa_df[con3 & con4])
# Out:
# 24918

# %%
len(visa_df[con3 & con4])/len(visa_df)
# Out:
# 0.9779434850863422

# %%
con5 = visa_df['prevailing_wage']>val_minus_3
con6 = visa_df['prevailing_wage']<val_plus_3
len(visa_df[con5 & con6])
# Out:
# 25069

# %%
len(visa_df[con5 & con6])/len(visa_df)
# Out:
# 0.9838697017268446

# %%
pyplot.hist(visa_df['prevailing_wage'],)
#By default it will give 10 intervals
# if you want more use bins
# Out:
# (array([2.4984e+04, 3.0500e+02, 1.2000e+02, 4.1000e+01, 1.5000e+01,
#         9.0000e+00, 5.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00]),
#  array([   6702.90665237,  329877.70583281,  653052.50501324,
#          976227.30419368, 1299402.10337411, 1622576.90255455,
#         1945751.70173499, 2268926.50091542, 2592101.30009586,
#         2915276.09927629, 3238450.89845673]),
#  <BarContainer object of 10 artists>)

# %%
pyplot.hist(visa_df['prevailing_wage'],bins=50)
# Out:
# (array([1.5666e+04, 7.7870e+03, 1.1430e+03, 2.6400e+02, 1.2400e+02,
#         8.3000e+01, 7.0000e+01, 6.3000e+01, 5.1000e+01, 3.8000e+01,
#         2.6000e+01, 3.1000e+01, 2.5000e+01, 2.4000e+01, 1.4000e+01,
#         1.7000e+01, 9.0000e+00, 4.0000e+00, 3.0000e+00, 8.0000e+00,
#         2.0000e+00, 4.0000e+00, 4.0000e+00, 4.0000e+00, 1.0000e+00,
#         0.0000e+00, 2.0000e+00, 4.0000e+00, 3.0000e+00, 0.0000e+00,
#         1.0000e+00, 2.0000e+00, 1.0000e+00, 0.0000e+00, 1.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00]),
#  array([   6702.90665237,   71337.86648846,  135972.82632455,
#          200607.78616063,  265242.74599672,  329877.70583281,
#          394512.6656689 ,  459147.62550498,  523782.58534107,
#          588417.54517716,  653052.50501324,  717687.46484933,
# ...

# %%
# it is the above output, now we are going to analyse that
(array([1.5666e+04, 7.7870e+03, 1.1430e+03, 2.6400e+02, 1.2400e+02,
        8.3000e+01, 7.0000e+01, 6.3000e+01, 5.1000e+01, 3.8000e+01,
        2.6000e+01, 3.1000e+01, 2.5000e+01, 2.4000e+01, 1.4000e+01,
        1.7000e+01, 9.0000e+00, 4.0000e+00, 3.0000e+00, 8.0000e+00,
        2.0000e+00, 4.0000e+00, 4.0000e+00, 4.0000e+00, 1.0000e+00,
        0.0000e+00, 2.0000e+00, 4.0000e+00, 3.0000e+00, 0.0000e+00,
        1.0000e+00, 2.0000e+00, 1.0000e+00, 0.0000e+00, 1.0000e+00,
        0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
        0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
        0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00]),
 array([   6702.90665237,   71337.86648846,  135972.82632455,
         200607.78616063,  265242.74599672,  329877.70583281,
         394512.6656689 ,  459147.62550498,  523782.58534107,
         588417.54517716,  653052.50501324,  717687.46484933,
         782322.42468542,  846957.3845215 ,  911592.34435759,
         976227.30419368, 1040862.26402977, 1105497.22386585,
        1170132.18370194, 1234767.14353803, 1299402.10337411,
        1364037.0632102 , 1428672.02304629, 1493306.98288238,
        1557941.94271846, 1622576.90255455, 1687211.86239064,
        1751846.82222672, 1816481.78206281, 1881116.7418989 ,
        1945751.70173499, 2010386.66157107, 2075021.62140716,
        2139656.58124325, 2204291.54107933, 2268926.50091542,
        2333561.46075151, 2398196.4205876 , 2462831.38042368,
        2527466.34025977, 2592101.30009586, 2656736.25993194,
        2721371.21976803, 2786006.17960412, 2850641.13944021,
        2915276.09927629, 2979911.05911238, 3044546.01894847,
        3109180.97878455, 3173815.93862064, 3238450.89845673]),
 <BarContainer object of 50 artists>)
# Out:
#   Cell In[443], line 16
#     <BarContainer object of 50 artists>)
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# - 1 observations are between 1.5666e+04 , 7.7870e+03
#
# - 5 observations are between 7.7870e+03, 1.1430e+03
#
# - 4 observations are between 1.1430e+03,  2.6400e+02
# - etc

# %%
#0 observations are between 1.5666e+04 , 7.7870e+03

#5 observations are between 7.7870e+03, 1.1430e+03

#4 observations are between 1.1430e+03,  2.6400e+02

# to verify this by conditions

cond1 = visa_df['prevailing_wage']>1.5666e+04
cond2 = visa_df['prevailing_wage']<7.7870e+03
cond1&cond2
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 25475    False
# 25476    False
# 25477    False
# 25478    False
# 25479    False
# Name: prevailing_wage, Length: 25480, dtype: bool

# %%
len(visa_df[cond1&cond2])
# Out:
# 0

# %%
# Instead of doing that all cond1...cond2... code like this
len(visa_df[visa_df['prevailing_wage'].between(2.0000e+00,1.0000e+00)])
# Out:
# 0

# %%
cond1 = visa_df['prevailing_wage']>7.7870e+03
cond2 = visa_df['prevailing_wage']<1.1430e+03
cond1&cond2
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 25475    False
# 25476    False
# 25477    False
# 25478    False
# 25479    False
# Name: prevailing_wage, Length: 25480, dtype: bool

# %%
len(visa_df[visa_df['prevailing_wage'].between(7.7870e+03,1.1430e+03)])
# Out:
# 0
